# %%
import seaborn as sns
import numpy as np
import pandas as pd

# %%
other_path = "https://raw.githubusercontent.com/carlosjara/eda_icesi/main/Notebooks/DataSet/SABERTYT20162.csv"
df = pd.read_csv(other_path,encoding = 'latin',delimiter=';',na_values=' ')
# Out:
# C:\Users\CARLOS\AppData\Local\Temp\ipykernel_27668\2800842167.py:2: DtypeWarning: Columns (11,12,14,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(other_path,encoding = 'latin',delimiter=';',na_values=' ')

# %%
df.shape
# Out:
# (53040, 104)

# %% [markdown]
# ## Ejercicio 1
#
# **Vea las últimas 10 filas del** ***dataframe*** **"df".** Ingrese sus líneas de código a continuación:

# %%
df.tail(10)
# Out:
#       ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO ESTU_FECHANACIMIENTO  \
# 53030                 CC        1 COLOMBIA           F           23/09/1992
# 53031                 CC        1 COLOMBIA           F            8/08/1993
# 53032                 CC        1 COLOMBIA           M           14/10/1981
# 53033                 CC        1 COLOMBIA           F            9/08/1986
# 53034                 CC        1 COLOMBIA           M           10/08/1995
# 53035                 CC        1 COLOMBIA           M           22/01/1992
# 53036                 CC        1 COLOMBIA           M            7/07/1992
# 53037                 CC        1 COLOMBIA           M            7/09/1988
# 53038                 CC        1 COLOMBIA           F            2/02/1994
# 53039                 CC        1 COLOMBIA           M           15/02/1988
#
#        PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_ESTADOCIVIL  \
# 53030    20164   EK201640038187      ESTUDIANTE           CASADO
# 53031    20164   EK201640028017      ESTUDIANTE          SOLTERO
# 53032    20164   EK201640008378      ESTUDIANTE           CASADO
# 53033    20164   EK201640024984      ESTUDIANTE          SOLTERO
# 53034    20164   EK201640017927      ESTUDIANTE          SOLTERO
# 53035    20164   EK201640005823      ESTUDIANTE          SOLTERO
# 53036    20164   EK201640005164      ESTUDIANTE          SOLTERO
# 53037    20164   EK201640001818      ESTUDIANTE      UNIÓN LIBRE
# 53038    20164   EK201640011583      ESTUDIANTE          SOLTERO
# 53039    20164   EK201640024848      ESTUDIANTE          SOLTERO
#
#       ESTU_TIENE_ETNIA ESTU_ETNIA  ... MOD_INGLES_DESEM MOD_INGLES_PNAL  \
# 53030               NO        NaN  ...              A1-              20
# 53031               NO        NaN  ...              A1-              16
# 53032               NO        NaN  ...               A1              27
# 53033               NO        NaN  ...               A1              59
# 53034               NO        NaN  ...               B1              91
# 53035               NO        NaN  ...               A1              38
# 53036               NO        NaN  ...               A1              48
# 53037               NO        NaN  ...               A1              31
# 53038               NO        NaN  ...               A1              53
# 53039               NO        NaN  ...              A1-               3
#
#       MOD_INGLES_PGREF MOD_COMUNI_ESCRITA_PUNT MOD_COMUNI_ESCRITA_DESEM  \
# 53030               12                   104.0                      3.0
# 53031               20                   104.0                      3.0
# 53032               33                    88.0                      2.0
# 53033               59                    79.0                      1.0
# 53034               77                    79.0                      1.0
# 53035               56                   104.0                      3.0
# 53036               68                    75.0                      1.0
# 53037               39                    60.0                      1.0
# 53038               63                   122.0                      4.0
# 53039                3                   118.0                      3.0
#
#       MOD_COMUNI_ESCRITA_PNAL  MOD_COMUNI_ESCRITA_PGREF ESTU_ESTADO  \
# 53030                    60.0                      60.0    PUBLICAR
# 53031                    56.0                      57.0    PUBLICAR
# 53032                    31.0                      32.0    PUBLICAR
# 53033                    17.0                      17.0    PUBLICAR
# 53034                    17.0                      18.0    PUBLICAR
# 53035                    57.0                      63.0    PUBLICAR
# 53036                    12.0                      15.0    PUBLICAR
# 53037                     2.0                       2.0    PUBLICAR
# 53038                    88.0                      89.0    PUBLICAR
# 53039                    80.0                      80.0    PUBLICAR
#
#               INSE   NSE
# 53030  49,44874434  NSE2
# 53031  43,10046976  NSE1
# 53032  55,88202537  NSE3
# 53033  34,65458932  NSE1
# 53034  58,50795831  NSE3
# 53035  45,34484192  NSE1
# 53036  39,95548887  NSE1
# 53037  60,76679974  NSE4
# 53038  69,01629674  NSE4
# 53039  41,91417628  NSE1
#
# [10 rows x 104 columns]

# %%
other_path = "https://raw.githubusercontent.com/lvmeninnovations/datasets/main/crispdm/auto.csv"
df = pd.read_csv(other_path,na_values=None)

# %%
df.shape
# Out:
# (204, 26)

# %%
df.tail(10)
# Out:
#      3    ? alfa-romero     gas    std   two convertible  rwd  front   88.6  \
# 194 -1   74       volvo     gas    std  four       wagon  rwd  front  104.3
# 195 -2  103       volvo     gas    std  four       sedan  rwd  front  104.3
# 196 -1   74       volvo     gas    std  four       wagon  rwd  front  104.3
# 197 -2  103       volvo     gas  turbo  four       sedan  rwd  front  104.3
# 198 -1   74       volvo     gas  turbo  four       wagon  rwd  front  104.3
# 199 -1   95       volvo     gas    std  four       sedan  rwd  front  109.1
# 200 -1   95       volvo     gas  turbo  four       sedan  rwd  front  109.1
# 201 -1   95       volvo     gas    std  four       sedan  rwd  front  109.1
# 202 -1   95       volvo  diesel  turbo  four       sedan  rwd  front  109.1
# 203 -1   95       volvo     gas  turbo  four       sedan  rwd  front  109.1
#
#      ...  130  mpfi  3.47  2.68   9.0  111  5000  21  27  13495
# 194  ...  141  mpfi  3.78  3.15   9.5  114  5400  23  28  13415
# 195  ...  141  mpfi  3.78  3.15   9.5  114  5400  24  28  15985
# 196  ...  141  mpfi  3.78  3.15   9.5  114  5400  24  28  16515
# 197  ...  130  mpfi  3.62  3.15   7.5  162  5100  17  22  18420
# 198  ...  130  mpfi  3.62  3.15   7.5  162  5100  17  22  18950
# 199  ...  141  mpfi  3.78  3.15   9.5  114  5400  23  28  16845
# 200  ...  141  mpfi  3.78  3.15   8.7  160  5300  19  25  19045
# 201  ...  173  mpfi  3.58  2.87   8.8  134  5500  18  23  21485
# 202  ...  145   idi  3.01  3.40  23.0  106  4800  26  27  22470
# 203  ...  141  mpfi  3.78  3.15   9.5  114  5400  19  25  22625
#
# [10 rows x 26 columns]

# %%
# Crear la lista de nombres para el encabezado
headers = ["factor-riesgo","perdida-promedio-anual","fabricante","tipo-combustible","aspiracion", "num-puertas","estilo-carroceria",
         "traccion","ubicacion-motor","distancia-entre-ejes", "longitud","anchura","altura","peso-vacio","tipo-motor",
         "num-cilindros", "tamano-motor","sistema-combustible","calibre","carrera","relacion-compresion","caballos-fuerza",
         "pico-rpm","millas_por_galon_ciudad","millas_por_galon_carretera","precio"]
df.columns = headers
df.head(10)
# Out:
#    factor-riesgo perdida-promedio-anual   fabricante tipo-combustible  \
# 0              3                      ?  alfa-romero              gas
# 1              1                      ?  alfa-romero              gas
# 2              2                    164         audi              gas
# 3              2                    164         audi              gas
# 4              2                      ?         audi              gas
# 5              1                    158         audi              gas
# 6              1                      ?         audi              gas
# 7              1                    158         audi              gas
# 8              0                      ?         audi              gas
# 9              2                    192          bmw              gas
#
#   aspiracion num-puertas estilo-carroceria traccion ubicacion-motor  \
# 0        std         two       convertible      rwd           front
# 1        std         two         hatchback      rwd           front
# 2        std        four             sedan      fwd           front
# 3        std        four             sedan      4wd           front
# 4        std         two             sedan      fwd           front
# 5        std        four             sedan      fwd           front
# 6        std        four             wagon      fwd           front
# 7      turbo        four             sedan      fwd           front
# 8      turbo         two         hatchback      4wd           front
# 9        std         two             sedan      rwd           front
#
#    distancia-entre-ejes  ...  tamano-motor  sistema-combustible  calibre  \
# 0                  88.6  ...           130                 mpfi     3.47
# 1                  94.5  ...           152                 mpfi     2.68
# 2                  99.8  ...           109                 mpfi     3.19
# 3                  99.4  ...           136                 mpfi     3.19
# 4                  99.8  ...           136                 mpfi     3.19
# 5                 105.8  ...           136                 mpfi     3.19
# 6                 105.8  ...           136                 mpfi     3.19
# 7                 105.8  ...           131                 mpfi     3.13
# 8                  99.5  ...           131                 mpfi     3.13
# 9                 101.2  ...           108                 mpfi     3.50
#
#    carrera relacion-compresion caballos-fuerza  pico-rpm  \
# 0     2.68                 9.0             111      5000
# 1     3.47                 9.0             154      5000
# 2     3.40                10.0             102      5500
# 3     3.40                 8.0             115      5500
# 4     3.40                 8.5             110      5500
# 5     3.40                 8.5             110      5500
# 6     3.40                 8.5             110      5500
# 7     3.40                 8.3             140      5500
# 8     3.40                 7.0             160      5500
# 9     2.80                 8.8             101      5800
#
#   millas_por_galon_ciudad millas_por_galon_carretera precio
# 0                      21                         27  16500
# 1                      19                         26  16500
# 2                      24                         30  13950
# 3                      18                         22  17450
# 4                      19                         25  15250
# 5                      19                         25  17710
# 6                      19                         25  18920
# 7                      17                         20  23875
# 8                      16                         22      ?
# 9                      23                         29  16430
#
# [10 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['factor-riesgo', 'perdida-promedio-anual', 'fabricante',
#        'tipo-combustible', 'aspiracion', 'num-puertas', 'estilo-carroceria',
#        'traccion', 'ubicacion-motor', 'distancia-entre-ejes', 'longitud',
#        'anchura', 'altura', 'peso-vacio', 'tipo-motor', 'num-cilindros',
#        'tamano-motor', 'sistema-combustible', 'calibre', 'carrera',
#        'relacion-compresion', 'caballos-fuerza', 'pico-rpm',
#        'millas_por_galon_ciudad', 'millas_por_galon_carretera', 'precio'],
#       dtype='object')

# %%
#from google.colab import files
df.to_csv("automobile.csv", index=False)
#files.download("automobile.csv")

# %% [markdown]
# También podemos leer y guardar otros tipos de formatos utilizando funciones similares a **`pd.read_csv()`** y **`df.to_csv()`**. La siguiente tabla muestra una lista de funciones que le pueden servir:
#
#
# | Data Formate  | Read           | Save             |
# | ------------- |:--------------:| ----------------:|
# | csv           | `pd.read_csv()`  |`df.to_csv()`     |
# | json          | `pd.read_json()` |`df.to_json()`    |
# | excel         | `pd.read_excel()`|`df.to_excel()`   |
# | hdf           | `pd.read_hdf()`  |`df.to_hdf()`     |
# | sql           | `pd.read_sql()`  |`df.to_sql()`     |
# | ...           |   ...          |       ...        |
